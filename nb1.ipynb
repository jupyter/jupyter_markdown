# %% [markdown]
# ## Example 1

# %% [markdown]
# 	foo	baz		bim

# %%
# %%html
# <pre><code>foo	baz		bim
# </code></pre>
# Out:
# <pre><code>foo	baz		bim
# </code></pre>

# %% [markdown]
# ## Example 2

# %% [markdown]
#   	foo	baz		bim

# %%
# %%html
# <pre><code>foo	baz		bim
# </code></pre>
# Out:
# <pre><code>foo	baz		bim
# </code></pre>

# %% [markdown]
# ## Example 3

# %% [markdown]
#     a	a
#     ὐ	a

# %%
# %%html
# <pre><code>a	a
# ὐ	a
# </code></pre>
# Out:
# <pre><code>a	a
# ὐ	a
# </code></pre>

# %% [markdown]
# ## Example 4

# %% [markdown]
#   - foo
#
# 	bar

# %%
# %%html
# <ul>
# <li>
# <p>foo</p>
# <p>bar</p>
# </li>
# </ul>
# Out:
# <ul>
# <li>
# <p>foo</p>
# <p>bar</p>
# </li>
# </ul>

# %% [markdown]
# ## Example 5

# %% [markdown]
# - foo
#
# 		bar

# %%
# %%html
# <ul>
# <li>
# <p>foo</p>
# <pre><code>  bar
# </code></pre>
# </li>
# </ul>
# Out:
# <ul>
# <li>
# <p>foo</p>
# <pre><code>  bar
# </code></pre>
# </li>
# </ul>

# %% [markdown]
# ## Example 6

# %% [markdown]
# >		foo

# %%
# %%html
# <blockquote>
# <pre><code>  foo
# </code></pre>
# </blockquote>
# Out:
# <blockquote>
# <pre><code>  foo
# </code></pre>
# </blockquote>

# %% [markdown]
# ## Example 7

# %% [markdown]
# -		foo

# %%
# %%html
# <ul>
# <li>
# <pre><code>  foo
# </code></pre>
# </li>
# </ul>
# Out:
# <ul>
# <li>
# <pre><code>  foo
# </code></pre>
# </li>
# </ul>

# %% [markdown]
# ## Example 8

# %% [markdown]
#     foo
# 	bar

# %%
# %%html
# <pre><code>foo
# bar
# </code></pre>
# Out:
# <pre><code>foo
# bar
# </code></pre>

# %% [markdown]
# ## Example 9

# %% [markdown]
#  - foo
#    - bar
# 	 - baz

# %%
# %%html
# <ul>
# <li>foo
# <ul>
# <li>bar
# <ul>
# <li>baz</li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# Out:
# <ul>
# <li>foo
# <ul>
# <li>bar
# <ul>
# <li>baz</li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>

# %% [markdown]
# ## Example 10

# %% [markdown]
# #	Foo

# %%
# %%html
# <h1>Foo</h1>
# Out:
# <h1>Foo</h1>

# %% [markdown]
# ## Example 11

# %% [markdown]
# *	*	*

# %%
# %%html
# <hr />
# Out:
# <hr />

# %% [markdown]
# ## Example 12

# %% [markdown]
# - `one
# - two`

# %%
# %%html
# <ul>
# <li>`one</li>
# <li>two`</li>
# </ul>
# Out:
# <ul>
# <li>`one</li>
# <li>two`</li>
# </ul>

# %% [markdown]
# ## Example 13

# %% [markdown]
# ***
# ---
# ___

# %%
# %%html
# <hr />
# <hr />
# <hr />
# Out:
# <hr />
# <hr />
# <hr />

# %% [markdown]
# ## Example 14

# %% [markdown]
# +++

# %%
# %%html
# <p>+++</p>
# Out:
# <p>+++</p>

# %% [markdown]
# ## Example 15

# %% [markdown]
# ===

# %%
# %%html
# <p>===</p>
# Out:
# <p>===</p>

# %% [markdown]
# ## Example 16

# %% [markdown]
# --
# **
# __

# %%
# %%html
# <p>--
# **
# __</p>
# Out:
# <p>--
# **
# __</p>

# %% [markdown]
# ## Example 17

# %% [markdown]
#  ***
#   ***
#    ***

# %%
# %%html
# <hr />
# <hr />
# <hr />
# Out:
# <hr />
# <hr />
# <hr />

# %% [markdown]
# ## Example 18

# %% [markdown]
#     ***

# %%
# %%html
# <pre><code>***
# </code></pre>
# Out:
# <pre><code>***
# </code></pre>

# %% [markdown]
# ## Example 19

# %% [markdown]
# Foo
#     ***

# %%
# %%html
# <p>Foo
# ***</p>
# Out:
# <p>Foo
# ***</p>

# %% [markdown]
# ## Example 20

# %% [markdown]
# _____________________________________

# %%
# %%html
# <hr />
# Out:
# <hr />

# %% [markdown]
# ## Example 21

# %% [markdown]
#  - - -

# %%
# %%html
# <hr />
# Out:
# <hr />

# %% [markdown]
# ## Example 22

# %% [markdown]
#  **  * ** * ** * **

# %%
# %%html
# <hr />
# Out:
# <hr />

# %% [markdown]
# ## Example 23

# %% [markdown]
# -     -      -      -

# %%
# %%html
# <hr />
# Out:
# <hr />

# %% [markdown]
# ## Example 24

# %% [markdown]
# - - - -

# %%
# %%html
# <hr />
# Out:
# <hr />

# %% [markdown]
# ## Example 25

# %% [markdown]
# _ _ _ _ a
#
# a------
#
# ---a---

# %%
# %%html
# <p>_ _ _ _ a</p>
# <p>a------</p>
# <p>---a---</p>
# Out:
# <p>_ _ _ _ a</p>
# <p>a------</p>
# <p>---a---</p>

# %% [markdown]
# ## Example 26

# %% [markdown]
#  *-*

# %%
# %%html
# <p><em>-</em></p>
# Out:
# <p><em>-</em></p>

# %% [markdown]
# ## Example 27

# %% [markdown]
# - foo
# ***
# - bar

# %%
# %%html
# <ul>
# <li>foo</li>
# </ul>
# <hr />
# <ul>
# <li>bar</li>
# </ul>
# Out:
# <ul>
# <li>foo</li>
# </ul>
# <hr />
# <ul>
# <li>bar</li>
# </ul>

# %% [markdown]
# ## Example 28

# %% [markdown]
# Foo
# ***
# bar

# %%
# %%html
# <p>Foo</p>
# <hr />
# <p>bar</p>
# Out:
# <p>Foo</p>
# <hr />
# <p>bar</p>

# %% [markdown]
# ## Example 29

# %% [markdown]
# Foo
# ---
# bar

# %%
# %%html
# <h2>Foo</h2>
# <p>bar</p>
# Out:
# <h2>Foo</h2>
# <p>bar</p>

# %% [markdown]
# ## Example 30

# %% [markdown]
# * Foo
# * * *
# * Bar

# %%
# %%html
# <ul>
# <li>Foo</li>
# </ul>
# <hr />
# <ul>
# <li>Bar</li>
# </ul>
# Out:
# <ul>
# <li>Foo</li>
# </ul>
# <hr />
# <ul>
# <li>Bar</li>
# </ul>

# %% [markdown]
# ## Example 31

# %% [markdown]
# - Foo
# - * * *

# %%
# %%html
# <ul>
# <li>Foo</li>
# <li>
# <hr />
# </li>
# </ul>
# Out:
# <ul>
# <li>Foo</li>
# <li>
# <hr />
# </li>
# </ul>

# %% [markdown]
# ## Example 32

# %% [markdown]
# # foo
# ## foo
# ### foo
# #### foo
# ##### foo
# ###### foo

# %%
# %%html
# <h1>foo</h1>
# <h2>foo</h2>
# <h3>foo</h3>
# <h4>foo</h4>
# <h5>foo</h5>
# <h6>foo</h6>
# Out:
# <h1>foo</h1>
# <h2>foo</h2>
# <h3>foo</h3>
# <h4>foo</h4>
# <h5>foo</h5>
# <h6>foo</h6>

# %% [markdown]
# ## Example 33

# %% [markdown]
# ####### foo

# %%
# %%html
# <p>####### foo</p>
# Out:
# <p>####### foo</p>

# %% [markdown]
# ## Example 34

# %% [markdown]
# #5 bolt
#
# #hashtag

# %%
# %%html
# <p>#5 bolt</p>
# <p>#hashtag</p>
# Out:
# <p>#5 bolt</p>
# <p>#hashtag</p>

# %% [markdown]
# ## Example 35

# %% [markdown]
# \## foo

# %%
# %%html
# <p>## foo</p>
# Out:
# <p>## foo</p>

# %% [markdown]
# ## Example 36

# %% [markdown]
# # foo *bar* \*baz\*

# %%
# %%html
# <h1>foo <em>bar</em> *baz*</h1>
# Out:
# <h1>foo <em>bar</em> *baz*</h1>

# %% [markdown]
# ## Example 37

# %% [markdown]
# #                  foo

# %%
# %%html
# <h1>foo</h1>
# Out:
# <h1>foo</h1>

# %% [markdown]
# ## Example 38

# %% [markdown]
#  ### foo
#   ## foo
#    # foo

# %%
# %%html
# <h3>foo</h3>
# <h2>foo</h2>
# <h1>foo</h1>
# Out:
# <h3>foo</h3>
# <h2>foo</h2>
# <h1>foo</h1>

# %% [markdown]
# ## Example 39

# %% [markdown]
#     # foo

# %%
# %%html
# <pre><code># foo
# </code></pre>
# Out:
# <pre><code># foo
# </code></pre>

# %% [markdown]
# ## Example 40

# %% [markdown]
# foo
#     # bar

# %%
# %%html
# <p>foo
# # bar</p>
# Out:
# <p>foo
# # bar</p>

# %% [markdown]
# ## Example 41

# %% [markdown]
# ## foo ##
#   ###   bar    ###

# %%
# %%html
# <h2>foo</h2>
# <h3>bar</h3>
# Out:
# <h2>foo</h2>
# <h3>bar</h3>

# %% [markdown]
# ## Example 42

# %% [markdown]
# # foo ##################################
# ##### foo ##

# %%
# %%html
# <h1>foo</h1>
# <h5>foo</h5>
# Out:
# <h1>foo</h1>
# <h5>foo</h5>

# %% [markdown]
# ## Example 43

# %% [markdown]
# ### foo ###

# %%
# %%html
# <h3>foo</h3>
# Out:
# <h3>foo</h3>

# %% [markdown]
# ## Example 44

# %% [markdown]
# ### foo ### b

# %%
# %%html
# <h3>foo ### b</h3>
# Out:
# <h3>foo ### b</h3>

# %% [markdown]
# ## Example 45

# %% [markdown]
# # foo#

# %%
# %%html
# <h1>foo#</h1>
# Out:
# <h1>foo#</h1>

# %% [markdown]
# ## Example 46

# %% [markdown]
# ### foo \###
# ## foo #\##
# # foo \#

# %%
# %%html
# <h3>foo ###</h3>
# <h2>foo ###</h2>
# <h1>foo #</h1>
# Out:
# <h3>foo ###</h3>
# <h2>foo ###</h2>
# <h1>foo #</h1>

# %% [markdown]
# ## Example 47

# %% [markdown]
# ****
# ## foo
# ****

# %%
# %%html
# <hr />
# <h2>foo</h2>
# <hr />
# Out:
# <hr />
# <h2>foo</h2>
# <hr />

# %% [markdown]
# ## Example 48

# %% [markdown]
# Foo bar
# # baz
# Bar foo

# %%
# %%html
# <p>Foo bar</p>
# <h1>baz</h1>
# <p>Bar foo</p>
# Out:
# <p>Foo bar</p>
# <h1>baz</h1>
# <p>Bar foo</p>

# %% [markdown]
# ## Example 49

# %% [markdown]
# ##
# #
# ### ###

# %%
# %%html
# <h2></h2>
# <h1></h1>
# <h3></h3>
# Out:
# <h2></h2>
# <h1></h1>
# <h3></h3>

# %% [markdown]
# ## Example 50

# %% [markdown]
# Foo *bar*
# =========
#
# Foo *bar*
# ---------

# %%
# %%html
# <h1>Foo <em>bar</em></h1>
# <h2>Foo <em>bar</em></h2>
# Out:
# <h1>Foo <em>bar</em></h1>
# <h2>Foo <em>bar</em></h2>

# %% [markdown]
# ## Example 51

# %% [markdown]
# Foo *bar
# baz*
# ====

# %%
# %%html
# <h1>Foo <em>bar
# baz</em></h1>
# Out:
# <h1>Foo <em>bar
# baz</em></h1>

# %% [markdown]
# ## Example 52

# %% [markdown]
# Foo
# -------------------------
#
# Foo
# =

# %%
# %%html
# <h2>Foo</h2>
# <h1>Foo</h1>
# Out:
# <h2>Foo</h2>
# <h1>Foo</h1>

# %% [markdown]
# ## Example 53

# %% [markdown]
#    Foo
# ---
#
#   Foo
# -----
#
#   Foo
#   ===

# %%
# %%html
# <h2>Foo</h2>
# <h2>Foo</h2>
# <h1>Foo</h1>
# Out:
# <h2>Foo</h2>
# <h2>Foo</h2>
# <h1>Foo</h1>

# %% [markdown]
# ## Example 54

# %% [markdown]
#     Foo
#     ---
#
#     Foo
# ---

# %%
# %%html
# <pre><code>Foo
# ---
#
# Foo
# </code></pre>
# <hr />
# Out:
# <pre><code>Foo
# ---
#
# Foo
# </code></pre>
# <hr />

# %% [markdown]
# ## Example 55

# %% [markdown]
# Foo
#    ----

# %%
# %%html
# <h2>Foo</h2>
# Out:
# <h2>Foo</h2>

# %% [markdown]
# ## Example 56

# %% [markdown]
# Foo
#     ---

# %%
# %%html
# <p>Foo
# ---</p>
# Out:
# <p>Foo
# ---</p>

# %% [markdown]
# ## Example 57

# %% [markdown]
# Foo
# = =
#
# Foo
# --- -

# %%
# %%html
# <p>Foo
# = =</p>
# <p>Foo</p>
# <hr />
# Out:
# <p>Foo
# = =</p>
# <p>Foo</p>
# <hr />

# %% [markdown]
# ## Example 58

# %% [markdown]
# Foo
# -----

# %%
# %%html
# <h2>Foo</h2>
# Out:
# <h2>Foo</h2>

# %% [markdown]
# ## Example 59

# %% [markdown]
# Foo\
# ----

# %%
# %%html
# <h2>Foo\</h2>
# Out:
# <h2>Foo\</h2>

# %% [markdown]
# ## Example 60

# %% [markdown]
# `Foo
# ----
# `
#
# <a title="a lot
# ---
# of dashes"/>

# %%
# %%html
# <h2>`Foo</h2>
# <p>`</p>
# <h2>&lt;a title=&quot;a lot</h2>
# <p>of dashes&quot;/&gt;</p>
# Out:
# <h2>`Foo</h2>
# <p>`</p>
# <h2>&lt;a title=&quot;a lot</h2>
# <p>of dashes&quot;/&gt;</p>

# %% [markdown]
# ## Example 61

# %% [markdown]
# > Foo
# ---

# %%
# %%html
# <blockquote>
# <p>Foo</p>
# </blockquote>
# <hr />
# Out:
# <blockquote>
# <p>Foo</p>
# </blockquote>
# <hr />

# %% [markdown]
# ## Example 62

# %% [markdown]
# > foo
# bar
# ===

# %%
# %%html
# <blockquote>
# <p>foo
# bar
# ===</p>
# </blockquote>
# Out:
# <blockquote>
# <p>foo
# bar
# ===</p>
# </blockquote>

# %% [markdown]
# ## Example 63

# %% [markdown]
# - Foo
# ---

# %%
# %%html
# <ul>
# <li>Foo</li>
# </ul>
# <hr />
# Out:
# <ul>
# <li>Foo</li>
# </ul>
# <hr />

# %% [markdown]
# ## Example 64

# %% [markdown]
# Foo
# Bar
# ---

# %%
# %%html
# <h2>Foo
# Bar</h2>
# Out:
# <h2>Foo
# Bar</h2>

# %% [markdown]
# ## Example 65

# %% [markdown]
# ---
# Foo
# ---
# Bar
# ---
# Baz

# %%
# %%html
# <hr />
# <h2>Foo</h2>
# <h2>Bar</h2>
# <p>Baz</p>
# Out:
# <hr />
# <h2>Foo</h2>
# <h2>Bar</h2>
# <p>Baz</p>

# %% [markdown]
# ## Example 66

# %% [markdown]
# ====

# %%
# %%html
# <p>====</p>
# Out:
# <p>====</p>

# %% [markdown]
# ## Example 67

# %% [markdown]
# ---
# ---

# %%
# %%html
# <hr />
# <hr />
# Out:
# <hr />
# <hr />

# %% [markdown]
# ## Example 68

# %% [markdown]
# - foo
# -----

# %%
# %%html
# <ul>
# <li>foo</li>
# </ul>
# <hr />
# Out:
# <ul>
# <li>foo</li>
# </ul>
# <hr />

# %% [markdown]
# ## Example 69

# %% [markdown]
#     foo
# ---

# %%
# %%html
# <pre><code>foo
# </code></pre>
# <hr />
# Out:
# <pre><code>foo
# </code></pre>
# <hr />

# %% [markdown]
# ## Example 70

# %% [markdown]
# > foo
# -----

# %%
# %%html
# <blockquote>
# <p>foo</p>
# </blockquote>
# <hr />
# Out:
# <blockquote>
# <p>foo</p>
# </blockquote>
# <hr />

# %% [markdown]
# ## Example 71

# %% [markdown]
# \> foo
# ------

# %%
# %%html
# <h2>&gt; foo</h2>
# Out:
# <h2>&gt; foo</h2>

# %% [markdown]
# ## Example 72

# %% [markdown]
# Foo
#
# bar
# ---
# baz

# %%
# %%html
# <p>Foo</p>
# <h2>bar</h2>
# <p>baz</p>
# Out:
# <p>Foo</p>
# <h2>bar</h2>
# <p>baz</p>

# %% [markdown]
# ## Example 73

# %% [markdown]
# Foo
# bar
#
# ---
#
# baz

# %%
# %%html
# <p>Foo
# bar</p>
# <hr />
# <p>baz</p>
# Out:
# <p>Foo
# bar</p>
# <hr />
# <p>baz</p>

# %% [markdown]
# ## Example 74

# %% [markdown]
# Foo
# bar
# * * *
# baz

# %%
# %%html
# <p>Foo
# bar</p>
# <hr />
# <p>baz</p>
# Out:
# <p>Foo
# bar</p>
# <hr />
# <p>baz</p>

# %% [markdown]
# ## Example 75

# %% [markdown]
# Foo
# bar
# \---
# baz

# %%
# %%html
# <p>Foo
# bar
# ---
# baz</p>
# Out:
# <p>Foo
# bar
# ---
# baz</p>

# %% [markdown]
# ## Example 76

# %% [markdown]
#     a simple
#       indented code block

# %%
# %%html
# <pre><code>a simple
#   indented code block
# </code></pre>
# Out:
# <pre><code>a simple
#   indented code block
# </code></pre>

# %% [markdown]
# ## Example 77

# %% [markdown]
#   - foo
#
#     bar

# %%
# %%html
# <ul>
# <li>
# <p>foo</p>
# <p>bar</p>
# </li>
# </ul>
# Out:
# <ul>
# <li>
# <p>foo</p>
# <p>bar</p>
# </li>
# </ul>

# %% [markdown]
# ## Example 78

# %% [markdown]
# 1.  foo
#
#     - bar

# %%
# %%html
# <ol>
# <li>
# <p>foo</p>
# <ul>
# <li>bar</li>
# </ul>
# </li>
# </ol>
# Out:
# <ol>
# <li>
# <p>foo</p>
# <ul>
# <li>bar</li>
# </ul>
# </li>
# </ol>

# %% [markdown]
# ## Example 79

# %% [markdown]
#     <a/>
#     *hi*
#
#     - one

# %%
# %%html
# <pre><code>&lt;a/&gt;
# *hi*
#
# - one
# </code></pre>
# Out:
# <pre><code>&lt;a/&gt;
# *hi*
#
# - one
# </code></pre>

# %% [markdown]
# ## Example 80

# %% [markdown]
#     chunk1
#
#     chunk2
#
#
#
#     chunk3

# %%
# %%html
# <pre><code>chunk1
#
# chunk2
#
#
#
# chunk3
# </code></pre>
# Out:
# <pre><code>chunk1
#
# chunk2
#
#
#
# chunk3
# </code></pre>

# %% [markdown]
# ## Example 81

# %% [markdown]
#     chunk1
#
#       chunk2

# %%
# %%html
# <pre><code>chunk1
#
#   chunk2
# </code></pre>
# Out:
# <pre><code>chunk1
#
#   chunk2
# </code></pre>

# %% [markdown]
# ## Example 82

# %% [markdown]
# Foo
#     bar

# %%
# %%html
# <p>Foo
# bar</p>
# Out:
# <p>Foo
# bar</p>

# %% [markdown]
# ## Example 83

# %% [markdown]
#     foo
# bar

# %%
# %%html
# <pre><code>foo
# </code></pre>
# <p>bar</p>
# Out:
# <pre><code>foo
# </code></pre>
# <p>bar</p>

# %% [markdown]
# ## Example 84

# %% [markdown]
# # Heading
#     foo
# Heading
# ------
#     foo
# ----

# %%
# %%html
# <h1>Heading</h1>
# <pre><code>foo
# </code></pre>
# <h2>Heading</h2>
# <pre><code>foo
# </code></pre>
# <hr />
# Out:
# <h1>Heading</h1>
# <pre><code>foo
# </code></pre>
# <h2>Heading</h2>
# <pre><code>foo
# </code></pre>
# <hr />

# %% [markdown]
# ## Example 85

# %% [markdown]
#         foo
#     bar

# %%
# %%html
# <pre><code>    foo
# bar
# </code></pre>
# Out:
# <pre><code>    foo
# bar
# </code></pre>

# %% [markdown]
# ## Example 86

# %% [markdown]
#
#     foo

# %%
# %%html
# <pre><code>foo
# </code></pre>
# Out:
# <pre><code>foo
# </code></pre>

# %% [markdown]
# ## Example 87

# %% [markdown]
#     foo

# %%
# %%html
# <pre><code>foo
# </code></pre>
# Out:
# <pre><code>foo
# </code></pre>

# %% [markdown]
# ## Example 88

# %% [markdown]
# ```
# <
#  >
# ```

# %%
# %%html
# <pre><code>&lt;
#  &gt;
# </code></pre>
# Out:
# <pre><code>&lt;
#  &gt;
# </code></pre>

# %% [markdown]
# ## Example 89

# %% [markdown]
# ~~~
# <
#  >
# ~~~

# %%
# %%html
# <pre><code>&lt;
#  &gt;
# </code></pre>
# Out:
# <pre><code>&lt;
#  &gt;
# </code></pre>

# %% [markdown]
# ## Example 90

# %% [markdown]
# ```
# aaa
# ~~~
# ```

# %%
# %%html
# <pre><code>aaa
# ~~~
# </code></pre>
# Out:
# <pre><code>aaa
# ~~~
# </code></pre>

# %% [markdown]
# ## Example 91

# %% [markdown]
# ~~~
# aaa
# ```
# ~~~

# %%
# %%html
# <pre><code>aaa
# ```
# </code></pre>
# Out:
# <pre><code>aaa
# ```
# </code></pre>

# %% [markdown]
# ## Example 92

# %% [markdown]
# ````
# aaa
# ```
# ``````

# %%
# %%html
# <pre><code>aaa
# ```
# </code></pre>
# Out:
# <pre><code>aaa
# ```
# </code></pre>

# %% [markdown]
# ## Example 93

# %% [markdown]
# ~~~~
# aaa
# ~~~
# ~~~~

# %%
# %%html
# <pre><code>aaa
# ~~~
# </code></pre>
# Out:
# <pre><code>aaa
# ~~~
# </code></pre>

# %% [markdown]
# ## Example 94

# %% [markdown]
# ```

# %%
# %%html
# <pre><code></code></pre>
# Out:
# <pre><code></code></pre>

# %% [markdown]
# ## Example 95

# %% [markdown]
# `````
#
# ```
# aaa

# %%
# %%html
# <pre><code>
# ```
# aaa
# </code></pre>
# Out:
# <pre><code>
# ```
# aaa
# </code></pre>

# %% [markdown]
# ## Example 96

# %% [markdown]
# > ```
# > aaa
#
# bbb

# %%
# %%html
# <blockquote>
# <pre><code>aaa
# </code></pre>
# </blockquote>
# <p>bbb</p>
# Out:
# <blockquote>
# <pre><code>aaa
# </code></pre>
# </blockquote>
# <p>bbb</p>

# %% [markdown]
# ## Example 97

# %% [markdown]
# ```
#
#
# ```

# %%
# %%html
# <pre><code>
#
# </code></pre>
# Out:
# <pre><code>
#
# </code></pre>

# %% [markdown]
# ## Example 98

# %% [markdown]
# ```
# ```

# %%
# %%html
# <pre><code></code></pre>
# Out:
# <pre><code></code></pre>

# %% [markdown]
# ## Example 99

# %% [markdown]
#  ```
#  aaa
# aaa
# ```

# %%
# %%html
# <pre><code>aaa
# aaa
# </code></pre>
# Out:
# <pre><code>aaa
# aaa
# </code></pre>

# %% [markdown]
# ## Example 100

# %% [markdown]
#   ```
# aaa
#   aaa
# aaa
#   ```

# %%
# %%html
# <pre><code>aaa
# aaa
# aaa
# </code></pre>
# Out:
# <pre><code>aaa
# aaa
# aaa
# </code></pre>
